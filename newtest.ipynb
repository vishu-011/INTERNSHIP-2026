# %%
import pandas as pd
data= pd.read_csv('House_Rent_Dataset.csv')
data.head()

y=data['Rent']
x= data.drop(['Rent','Posted On', 'Area Type','City'], axis=1)

import category_encoders as ce
encoder = ce.LeaveOneOutEncoder(return_df= True)
X =encoder.fit_transform(x, y)

print(X)
# Out:
#       BHK  Size         Floor  Area Locality  Furnishing Status  \
# 0       2  1100  14164.719198    6500.000000       22468.505513
# 1       2   800  17947.602740    3500.000000       38727.130222
# 2       2  1000  17957.876712   23600.000000       38728.463556
# 3       2   800  14458.465608   22000.000000       22468.505513
# 4       2   850  14465.079365   34993.451327       22469.883682
# ...   ...   ...           ...            ...                ...
# 4741    2  1000  22249.168675   16500.000000       38729.352444
# 4742    3  2000  25119.095477   34993.451327       38723.130222
# 4743    3  1750  22008.204819   30000.000000       38720.463556
# 4744    3  1500  34993.451327   43839.285714       38716.019111
# 4745    2  1000  18794.117647   15750.000000       22465.749173
#
#       Tenant Preferred  Bathroom  Point of Contact
# 0         31216.953238         2      16706.291757
# 1         31214.048795         1      16703.181337
# ...

# %%
y=data['Rent']
x=data.drop(['Rent','Posted On','Floor','Area Locality'],axis=1)

# %%
import category_encoders as ce
encoder=ce.LeaveOneOutEncoder()
X = encoder.fit_transform(x,y)

# %%
print(X)
# Out:
#       BHK  Size     Area Type          City  Furnishing Status  \
# 0       2  1100  18676.943967  11648.319312       22468.505513
# 1       2   800  18672.853988  11629.198853       38727.130222
# 2       2  1000  18674.080982  11634.934990       38728.463556
# 3       2   800  18676.943967  11648.319312       22468.505513
# 4       2   850  52405.438398  11653.099426       22469.883682
# ...   ...   ...           ...           ...                ...
# 4741    2  1000  52402.173269  20561.455594       38729.352444
# 4742    3  2000  18669.173006  20545.307958       38723.130222
# 4743    3  1750  52393.466260  20538.387543       38720.463556
# 4744    3  1500  52389.112756  20526.853518       38716.019111
# 4745    2  1000  52402.173269  20561.455594       22465.749173
#
#       Tenant Preferred  Bathroom  Point of Contact
# 0         31216.953238         2      16706.291757
# 1         31214.048795         1      16703.181337
# 2         31214.920128         1      16704.114463
# ...

# %%
#min-max scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x=scaler.fit_transform(X)
print(x)
# Out:
# [[0.2        0.13642053 0.27316184 ... 0.01795978 0.11111111 0.00321938]
#  [0.2        0.09887359 0.27307371 ... 0.01780886 0.         0.00316481]
#  [0.2        0.12390488 0.27310014 ... 0.01785413 0.         0.00318118]
#  ...
#  [0.4        0.21777222 0.99968293 ... 0.01758247 0.22222222 0.99965557]
#  [0.4        0.1864831  0.99958912 ... 0.99558704 0.11111111 0.99954076]
#  [0.2        0.12390488 0.99987054 ... 0.58744851 0.11111111 0.00319209]]

# %%
import pandas as pd
x = pd.DataFrame(x, columns=X.columns)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
y_pred = model.predict(x_test)

print(y_pred[:5])
# Out:
# [ 24794.83992961  16474.50895253  62990.01833866  63126.35766695
#  100790.96983036]

# %%
y_pred = model.predict(x_test)

print(y_pred[:5])
# Out:
# [ 24794.83992961  16474.50895253  62990.01833866  63126.35766695
#  100790.96983036]

# %%
new_house = pd.DataFrame({
    'BHK': [2],
    'Size': [1200],
    'Area Type': ['Super Area'],
    'City': ['Delhi'],
    'Furnishing Status': ['Semi-Furnished'],
    'Tenant Preferred': ['Family'],
    'Bathroom': [2],
    'Point of Contact': ['Contact Owner']
})

new_encoded = encoder.transform(new_house)
new_scaled = scaler.transform(new_encoded)
prediction = model.predict(new_scaled)
print("Predicted Rent:", prediction[0])
# Out:
# Predicted Rent: 23822.757353939065
# c:\Users\meetv\OneDrive\internship 2026\srm\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import joblib
saved_data = {
    "encoder": encoder,
    "scaler": scaler,
    "model": model
}

# Save the dictionary to a .pkl file
joblib.dump(saved_data, "house_rent_prediction.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import joblib
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
import category_encoders
import joblib
encoder = ce.LeaveOneOutEncoder()
X = encoder.fit_transform(x, y)
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Assuming you have already trained these three objects in your code:
# 1. your_encoder  (e.g., OneHotEncoder or LabelEncoder)
# 2. your_scaler   (e.g., StandardScaler or MinMaxScaler)
# 3. your_model    (e.g., LinearRegression, RandomForestRegressor, etc.)

# Create a dictionary matching what hpp.py expects to load
saved_data = {
    "encoder": encoder,
    "scaler": scaler,
    "model": model
}

# Save the dictionary to a .pkl file
joblib.dump(saved_data, "house_rent_prediction.pkl")

print("Model saved successfully!")
# Out:
# ...
# Model saved successfully!

# %%
import joblib

# Assuming you have already trained these three objects in your code:
# 1. your_encoder  (e.g., OneHotEncoder or LabelEncoder)
# 2. your_scaler   (e.g., StandardScaler or MinMaxScaler)
# 3. your_model    (e.g., LinearRegression, RandomForestRegressor, etc.)

# Create a dictionary matching what hpp.py expects to load
saved_data = {
    "encoder": encoder,
    "scaler": scaler,
    "model": model
}

# Save the dictionary to a .pkl file
joblib.dump(saved_data, "house_rent_prediction.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
print(type(encoder))
import joblib
import pandas as pd
import category_encoders as ce
hpp=joblib.load("house_rent_prediction.pkl")
encoder=hpp["encoder"]
scaler=hpp["scaler"]
model=hpp["model"]
new_house = pd.DataFrame({
'BHK': [2],
'Size': [1200],
'Area Type': ['Super Area'],
'City': ['Delhi'],
'Furnishing Status': ['Semi-Furnished'],
'Tenant Preferred': ['Family'],
'Bathroom': [2],
'Point of Contact': ['Contact Owner']
})

new_encoded = encoder.transform(new_house) 
new_scaled = scaler.transform(new_encoded) 
prediction = model.predict(new_scaled)
print("Predicted Rent:", prediction[0])
# Out:
# <class 'category_encoders.leave_one_out.LeaveOneOutEncoder'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 21
#      17 'Point of Contact': ['Contact Owner']
#      18 })
#      19
#      20 new_encoded = encoder.transform(new_house)
# ---> 21 new_scaled = scaler.transform(new_encoded)
#      22 prediction = model.predict(new_scaled)
#      23 print("Predicted Rent:", prediction[0])
#
# File c:\Users\meetv\OneDrive\internship 2026\srm\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
# ...

# %%
import joblib
import pandas as pd
import category_encoders as ce
hpp=joblib.load("house_rent_prediction.pkl")
encoder=hpp["encoder"]
scaler=hpp["scaler"]
model=hpp["model"]
new_house = pd.DataFrame({
'BHK': [2],
'Size': [1200],
'Area Type': ['Super Area'],
'City': ['Delhi'],
'Furnishing Status': ['Semi-Furnished'],
'Tenant Preferred': ['Family'],
'Bathroom': [2],
'Point of Contact': ['Contact Owner']
})

new_encoded = encoder.transform(new_house) 
new_scaled = scaler.transform(new_encoded) 
prediction = model.predict(new_scaled) 
print("Predicted Rent:", prediction[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 20
#      16 'Point of Contact': ['Contact Owner']
#      17 })
#      18
#      19 new_encoded = encoder.transform(new_house)
# ---> 20 new_scaled = scaler.transform(new_encoded)
#      21 prediction = model.predict(new_scaled)
#      22 print("Predicted Rent:", prediction[0])
#
# File c:\Users\meetv\OneDrive\internship 2026\srm\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
# ...
